# %% [markdown]
# #### Webscraping using Python ( Example 1 )
#
# References:
# https://first-web-scraper.readthedocs.io/en/latest/
# http://web.stanford.edu/~zlotnick/TextAsData/Web_Scraping_with_Beautiful_Soup.html
# http://altitudelabs.com/blog/web-scraping-with-python-and-beautiful-soup/
#
# Installation:
# `pip install BS4`  |
# `pip install Requests`

# %%
# !pip install BS4
# !pip install Requests
# Out:
# Collecting BS4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Requirement already satisfied: beautifulsoup4 in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (from BS4) (4.8.0)
# Requirement already satisfied: soupsieve>=1.2 in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (from beautifulsoup4->BS4) (1.9.3)
# Building wheels for collected packages: BS4
#   Building wheel for BS4 (setup.py) ... done
#   Created wheel for BS4: filename=bs4-0.0.1-cp37-none-any.whl size=1273 sha256=9d85e7b7f31970d459db4495e2176bfe0be422c46483560dc10741d055f7fafa
#   Stored in directory: /Users/sbharadwaj/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built BS4
# Installing collected packages: BS4
# Successfully installed BS4-0.0.1
# Requirement already satisfied: Requests in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (2.22.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (from Requests) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (from Requests) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (from Requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages (from Requests) (1.24.2)

# %%
import csv
import requests
from bs4 import BeautifulSoup
from IPython.display import HTML

# %% [markdown]
# Scraping Rules
# --------------
# - You should check a website’s Terms and Conditions before you scrape it. Be careful to read the statements about legal use of data. Usually, the data you scrape should not be used for commercial purposes.
# - Do not request data from the website too aggressively with your program (also known as spamming), as this may break the website. Make sure your program behaves in a reasonable manner (i.e. acts like a human). One request for one webpage per second is good practice.
# - The layout of a website may change from time to time, so make sure to revisit the site and rewrite your code as needed

# %%
# scrape the current Detainees of Boone County Jail from webpage into CSV
url = 'https://report.boonecountymo.org/mrcjava/servlet/SH01_MP.I00290s'
headers = {'User-Agent': "Chrome/54.0.2840.90"}
response = requests.get(url, headers=headers)
html = response.content

# %%
HTML('<iframe src=http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp width=900 height=350></iframe>')
# Out:
# /Users/sbharadwaj/opt/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:694: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp width=900 height=350></iframe>

# %%
soup = BeautifulSoup(html, "lxml")
table = soup.find('tbody', attrs={'class': 'stripe'})

# %%
tmpRow = (table.findAll('tr')[1:])
print (tmpRow)
# Out:
# [<tr class="even">
# <td class="two td_left" data-th="Last Name">ADAMS</td>
# <td class="two td_left" data-th="First Name">JEREMIAH</td>
# <td class="two td_left" data-th="Middle Name">SETH</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">45</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=2885&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">ADAMS</td>
# <td class="one td_left" data-th="First Name">LACEE</td>
# <td class="one td_left" data-th="Middle Name">KABRINA</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">F</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">24</td>
# <td class="one td_left" data-th="City">ARMSTRONG</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=3156&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">AHMED</td>
# <td class="two td_left" data-th="First Name">ELSADIG</td>
# <td class="two td_left" data-th="Middle Name">IBRAHIM SALIH</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">34</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=126&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">ARMSTRONG</td>
# <td class="one td_left" data-th="First Name">TYRONE</td>
# <td class="one td_left" data-th="Middle Name">MARTEZ</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">28</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=2292&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">ARNOLD</td>
# <td class="two td_left" data-th="First Name">JESSE</td>
# <td class="two td_left" data-th="Middle Name">LEE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">38</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=5734&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">AUNGERER</td>
# <td class="one td_left" data-th="First Name">MARK</td>
# <td class="one td_left" data-th="Middle Name">CHARLES</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">53</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=1475&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">AYALA</td>
# <td class="two td_left" data-th="First Name">CARLOS</td>
# <td class="two td_left" data-th="Middle Name">MARCOS</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">U</td>
# <td class="two td_right" data-th="Age">33</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=3716&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BAKER</td>
# <td class="one td_left" data-th="First Name">CHRISTOPHER</td>
# <td class="one td_left" data-th="Middle Name">ALLAN</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">30</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=1794&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BALDWIN</td>
# <td class="two td_left" data-th="First Name">SAM</td>
# <td class="two td_left" data-th="Middle Name"> </td>
# <td class="two td_left" data-th="Suffix">IV</td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">28</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=5975&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BANKS</td>
# <td class="one td_left" data-th="First Name">TIMOTHY</td>
# <td class="one td_left" data-th="Middle Name">MAURICE</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">39</td>
# <td class="one td_left" data-th="City">KANSAS CITY</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=103&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BANN</td>
# <td class="two td_left" data-th="First Name">MATTHEW</td>
# <td class="two td_left" data-th="Middle Name">DAVID</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">18</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=95&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BARAJAS-REAL</td>
# <td class="one td_left" data-th="First Name">EUSEBIO</td>
# <td class="one td_left" data-th="Middle Name">DANIEL</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">29</td>
# <td class="one td_left" data-th="City">ASHLAND</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=2181&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BARNHART</td>
# <td class="two td_left" data-th="First Name">MILES</td>
# <td class="two td_left" data-th="Middle Name">VINCENT</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">30</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=7317&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BARTON</td>
# <td class="one td_left" data-th="First Name">KRISTE</td>
# <td class="one td_left" data-th="Middle Name">MARIE</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">F</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">34</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=5203&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BATES</td>
# <td class="two td_left" data-th="First Name">NATHAN</td>
# <td class="two td_left" data-th="Middle Name">ROBERT</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">35</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=419&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BATISTE</td>
# <td class="one td_left" data-th="First Name">WALTER</td>
# <td class="one td_left" data-th="Middle Name">ALLEN</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">28</td>
# <td class="one td_left" data-th="City">ST.LOUIS</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=350&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BELL</td>
# <td class="two td_left" data-th="First Name">COLIN</td>
# <td class="two td_left" data-th="Middle Name">KEITH</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">37</td>
# <td class="two td_left" data-th="City">HALLSVILLE</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=5391&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BENNETT</td>
# <td class="one td_left" data-th="First Name">JAMES</td>
# <td class="one td_left" data-th="Middle Name">DAVID</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">46</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=7314&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BENZ</td>
# <td class="two td_left" data-th="First Name">WILLIAM</td>
# <td class="two td_left" data-th="Middle Name">ERNEST</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">30</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=3629&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BERARDI</td>
# <td class="one td_left" data-th="First Name">DEBORAH</td>
# <td class="one td_left" data-th="Middle Name">EVA</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">F</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">58</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=1918&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BILDERBACK</td>
# <td class="two td_left" data-th="First Name">BRETT</td>
# <td class="two td_left" data-th="Middle Name">WAYNE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">43</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=4288&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BLACKWELL</td>
# <td class="one td_left" data-th="First Name">BRANDON</td>
# <td class="one td_left" data-th="Middle Name">CURTIS</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">36</td>
# <td class="one td_left" data-th="City">MOBERLY</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=564&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BLEY</td>
# <td class="two td_left" data-th="First Name">KATHALEEN</td>
# <td class="two td_left" data-th="Middle Name">NICOLE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">F</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">27</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=7190&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BOAZ</td>
# <td class="one td_left" data-th="First Name">ADAM</td>
# <td class="one td_left" data-th="Middle Name">RHEA</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">29</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=6828&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BOLEY</td>
# <td class="two td_left" data-th="First Name">JASON</td>
# <td class="two td_left" data-th="Middle Name">LEE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">40</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=390&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BOMBACK</td>
# <td class="one td_left" data-th="First Name">RICHARD</td>
# <td class="one td_left" data-th="Middle Name">JASON</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">33</td>
# <td class="one td_left" data-th="City">OWENSVILLE</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=3100&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BONAPARTE</td>
# <td class="two td_left" data-th="First Name">FRANK</td>
# <td class="two td_left" data-th="Middle Name">CORTEZ</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">38</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=156&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BOWDEN</td>
# <td class="one td_left" data-th="First Name">KENNETH</td>
# <td class="one td_left" data-th="Middle Name">LEE</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">39</td>
# <td class="one td_left" data-th="City">CLARK</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=4537&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BOWENS</td>
# <td class="two td_left" data-th="First Name">BRANDON</td>
# <td class="two td_left" data-th="Middle Name">DURELL</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">36</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=3549&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BRADFORD</td>
# <td class="one td_left" data-th="First Name">GAVIN</td>
# <td class="one td_left" data-th="Middle Name">CONNER</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">33</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=7515&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BRADFORD</td>
# <td class="two td_left" data-th="First Name">JEFFREY</td>
# <td class="two td_left" data-th="Middle Name">WAYNE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">38</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=1663&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BRADLEY</td>
# <td class="one td_left" data-th="First Name">ERIN</td>
# <td class="one td_left" data-th="Middle Name">ASHLEY</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">F</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">27</td>
# <td class="one td_left" data-th="City">IGNACIO</td>
# <td class="one td_left" data-th="State">CO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=7320&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BRADLEY</td>
# <td class="two td_left" data-th="First Name">ZACHARY</td>
# <td class="two td_left" data-th="Middle Name">DONOVAN</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">23</td>
# <td class="two td_left" data-th="City">CENTRALIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=7568&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BREEDLOVE</td>
# <td class="one td_left" data-th="First Name">WILLIAM</td>
# <td class="one td_left" data-th="Middle Name">LEE</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">56</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=413&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BRESEE</td>
# <td class="two td_left" data-th="First Name">JAMES</td>
# <td class="two td_left" data-th="Middle Name">ANTONIO</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">37</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=5527&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BREWER</td>
# <td class="one td_left" data-th="First Name">SEVANCE</td>
# <td class="one td_left" data-th="Middle Name">JTRI</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">28</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=4484&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BRIMMAGE</td>
# <td class="two td_left" data-th="First Name">CORTEZ</td>
# <td class="two td_left" data-th="Middle Name">LORENZO</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">29</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=63&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BROWN</td>
# <td class="one td_left" data-th="First Name">BARRY</td>
# <td class="one td_left" data-th="Middle Name">RONELL</td>
# <td class="one td_left" data-th="Suffix">II</td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">33</td>
# <td class="one td_left" data-th="City">FLORISSANT</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=486&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BROWN</td>
# <td class="two td_left" data-th="First Name">COURTNEY</td>
# <td class="two td_left" data-th="Middle Name">ANTRON</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">35</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=6646&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BROWN</td>
# <td class="one td_left" data-th="First Name">FELICIA</td>
# <td class="one td_left" data-th="Middle Name">DAWN</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">F</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">28</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=2499&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BULLOCK</td>
# <td class="two td_left" data-th="First Name">CHRISTOPHER</td>
# <td class="two td_left" data-th="Middle Name">AARON</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">48</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=484&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BURCH</td>
# <td class="one td_left" data-th="First Name">KESHIA</td>
# <td class="one td_left" data-th="Middle Name">LANAE</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">F</td>
# <td class="one td_left" data-th="Race">I</td>
# <td class="one td_right" data-th="Age">30</td>
# <td class="one td_left" data-th="City">COLUMBIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=1665&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BURKS</td>
# <td class="two td_left" data-th="First Name">HUNTER</td>
# <td class="two td_left" data-th="Middle Name">TRAVIS</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">24</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=162&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BURKS-MATHENY</td>
# <td class="one td_left" data-th="First Name">NOAH</td>
# <td class="one td_left" data-th="Middle Name">CHRISTIANSON</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">21</td>
# <td class="one td_left" data-th="City">SPRINGFIELD</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=1688&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BUSH</td>
# <td class="two td_left" data-th="First Name">CARL</td>
# <td class="two td_left" data-th="Middle Name">PATRICK</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">W</td>
# <td class="two td_right" data-th="Age">60</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=7303&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BUSHDIECKER</td>
# <td class="one td_left" data-th="First Name">HARLEY</td>
# <td class="one td_left" data-th="Middle Name">GENE</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">W</td>
# <td class="one td_right" data-th="Age">23</td>
# <td class="one td_left" data-th="City">CENTRALIA</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=7591&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">BUTLER</td>
# <td class="two td_left" data-th="First Name">ALBERT</td>
# <td class="two td_left" data-th="Middle Name">LEE</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">38</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=6649&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="odd">
# <td class="one td_left" data-th="Last Name">BUTLER</td>
# <td class="one td_left" data-th="First Name">JEMELL</td>
# <td class="one td_left" data-th="Middle Name">DUPRUE</td>
# <td class="one td_left" data-th="Suffix"> </td>
# <td class="one td_left" data-th="Sex">M</td>
# <td class="one td_left" data-th="Race">B</td>
# <td class="one td_right" data-th="Age">23</td>
# <td class="one td_left" data-th="City">JEFFERSON CITY</td>
# <td class="one td_left" data-th="State">MO</td>
# <td class="one td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=5849&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="even">
# <td class="two td_left" data-th="Last Name">CALMESE</td>
# <td class="two td_left" data-th="First Name">ANDREW</td>
# <td class="two td_left" data-th="Middle Name">MARTIN</td>
# <td class="two td_left" data-th="Suffix"> </td>
# <td class="two td_left" data-th="Sex">M</td>
# <td class="two td_left" data-th="Race">B</td>
# <td class="two td_right" data-th="Age">35</td>
# <td class="two td_left" data-th="City">COLUMBIA</td>
# <td class="two td_left" data-th="State">MO</td>
# <td class="two td_left" data-th="">
# <a class="_lookup btn btn-primary" height="600" href="RMS01_MP.R00040s?run=2&amp;R001=&amp;R002=&amp;ID=6157&amp;hover_redir=&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860"><i class="fa fa-large fa-fw fa-list-alt"> </i>Details</a>
# </td>
# </tr>, <tr class="tr-paging">
# <th class="th_left paging_row bottomPaging" colspan="93">  Detainee Count: 313
#                     <div class="pagination pagination-right fixed-pagination" style="margin-left: 2em;">
# <ul>
# <li>
# <a class="page-button" data-pagetype="btn_top" href="javascript:void(0)"><i class="fa fa-angle-double-left fa-large"> </i></a>
# </li>
# <li>
# <a class="page-button" data-pagetype="btn_prev" href="javascript:void(0)"><i class="fa fa-angle-left fa-large"> </i></a>
# </li>
# <li class="disabled">
# <a href="#">Page 1 of 7</a>
# </li>
# <li>
# <a class="page-button" data-pagetype="btn_next" href="javascript:void(0)"><i class="fa fa-angle-right fa-large"> </i></a>
# </li>
# <li>
# <a class="page-button" data-pagetype="btn_btmm" href="javascript:void(0)"><i class="fa fa-angle-double-right fa-large"> </i></a>
# </li>
# </ul>
# </div>
# </th>
# </tr>]

# %%
### Editing the code to fetch details of every record. The 'Case Number' and 'Charge Description' is Fetched for every Record.
list_of_rows = []
try:
    outfile = open("./inmates.csv", "w")
    writer = csv.writer(outfile)
    writer.writerow(["Last", "First", "Middle", "Gender", "Race", "Age", "City", "State","Case Number","Charge Description"])
    for row in table.findAll('tr'):
        list_of_cells = []
        for cell in row.findAll("td"):
            if(cell['data-th'] == ''):
                continue
            text = cell.text.replace('&nbsp;', '')
            list_of_cells.append(text)
        for anchor in row.findAll('a'):
            #href is fetched for every record and the response is parsed for every individual hit to href.
            details_href = "https://report.boonecountymo.org/mrcjava/servlet/"+anchor['href']
            details_response = requests.get(details_href)
            details_html = details_response.content
            details_soup = BeautifulSoup(details_html, "lxml")
            details_table = details_soup.find('tbody', attrs={'class': 'stripe'})
            if details_table is not None:
                details_table_tr = details_table.find('tr', attrs={"class": "detailBackground"})
                if details_table_tr is not None:
                    list_of_cells.append((details_table_tr.find('td', attrs = {'data-th' : 'CASE #'})).text)
                    list_of_cells.append((details_table_tr.find('td', attrs = {'data-th' : 'CHARGE DESCRIPTION'})).text)
        arrLength = len(list_of_cells)
        writer.writerow(list_of_cells)
finally:
    outfile.close()

# %%
# data cleaning 
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./inmates.csv')
df.head()
# Out:
#         Last     First         Middle Gender Race Age  City      State  \
# 0       ADAM      OMER          SIRAJ           M   B    32   COLUMBIA
# 1      ADAMS  JEREMIAH           SETH           M   W    45   COLUMBIA
# 2      ADAMS     LACEE        KABRINA           F   B    24  ARMSTRONG
# 3      AHMED   ELSADIG  IBRAHIM SALIH           M   B    34   COLUMBIA
# 4  ARMSTRONG    TYRONE         MARTEZ           M   B    28   COLUMBIA
#
#   Case Number  Charge Description
# 0          MO                 NaN
# 1          MO                 NaN
# 2          MO                 NaN
# 3          MO                 NaN
# 4          MO                 NaN

# %%
# Drop certain fields if they are not relevant for analysis
df.drop(['Race'], inplace=True, axis=1)
df.head()
# Out:
#         Last     First         Middle Gender Age  City      State Case Number  \
# 0       ADAM      OMER          SIRAJ          B    32   COLUMBIA          MO
# 1      ADAMS  JEREMIAH           SETH          W    45   COLUMBIA          MO
# 2      ADAMS     LACEE        KABRINA          B    24  ARMSTRONG          MO
# 3      AHMED   ELSADIG  IBRAHIM SALIH          B    34   COLUMBIA          MO
# 4  ARMSTRONG    TYRONE         MARTEZ          B    28   COLUMBIA          MO
#
#    Charge Description
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# Expanding M as Male and F as Female.
gender = df['Gender']
male = gender.str.contains('M')
female = gender.str.contains('F')
df['Gender'] = np.where(male, 'Male',
                       np.where(female, 'Female',
                               gender))
df.head()
# Out:
#         Last     First         Middle Gender Age  City      State Case Number  \
# 0       ADAM      OMER          SIRAJ          B    32   COLUMBIA          MO
# 1      ADAMS  JEREMIAH           SETH          W    45   COLUMBIA          MO
# 2      ADAMS     LACEE        KABRINA          B    24  ARMSTRONG          MO
# 3      AHMED   ELSADIG  IBRAHIM SALIH          B    34   COLUMBIA          MO
# 4  ARMSTRONG    TYRONE         MARTEZ          B    28   COLUMBIA          MO
#
#    Charge Description
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# Check for missing values in Case Number
df['Case Number'].isnull().values.any()
# Out:
# False

# %%
# Fill In missing values with a default value
df['Case Number'].fillna("No Case Number Available", inplace=True)
df['Charge Description'].fillna("No Description Available", inplace=True)
df.head()
# Out:
#         Last     First         Middle Gender Age  City      State Case Number  \
# 0       ADAM      OMER          SIRAJ          B    32   COLUMBIA          MO
# 1      ADAMS  JEREMIAH           SETH          W    45   COLUMBIA          MO
# 2      ADAMS     LACEE        KABRINA          B    24  ARMSTRONG          MO
# 3      AHMED   ELSADIG  IBRAHIM SALIH          B    34   COLUMBIA          MO
# 4  ARMSTRONG    TYRONE         MARTEZ          B    28   COLUMBIA          MO
#
#          Charge Description
# 0  No Description Available
# 1  No Description Available
# 2  No Description Available
# 3  No Description Available
# 4  No Description Available

# %%
# Remove whitespaces from Charge description and changing to uppercase
df['Charge Description'] = df['Charge Description'].str.strip()
df['Charge Description'] = df['Charge Description'].str.upper()
df.head()
# Out:
#         Last     First         Middle Gender Age  City      State Case Number  \
# 0       ADAM      OMER          SIRAJ          B    32   COLUMBIA          MO
# 1      ADAMS  JEREMIAH           SETH          W    45   COLUMBIA          MO
# 2      ADAMS     LACEE        KABRINA          B    24  ARMSTRONG          MO
# 3      AHMED   ELSADIG  IBRAHIM SALIH          B    34   COLUMBIA          MO
# 4  ARMSTRONG    TYRONE         MARTEZ          B    28   COLUMBIA          MO
#
#          Charge Description
# 0  NO DESCRIPTION AVAILABLE
# 1  NO DESCRIPTION AVAILABLE
# 2  NO DESCRIPTION AVAILABLE
# 3  NO DESCRIPTION AVAILABLE
# 4  NO DESCRIPTION AVAILABLE

# %%
# save final results
df.to_csv("./cleaninmates.csv")
